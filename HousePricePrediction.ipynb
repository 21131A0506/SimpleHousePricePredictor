# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Housing.csv")

# %%
print(data)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2)

# %%
train_data = X_train.join(Y_train)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925028           -0.107844     0.045973
# latitude            -0.925028  1.000000            0.010201    -0.034833
# housing_median_age  -0.107844  0.010201            1.000000    -0.361932
# total_rooms          0.045973 -0.034833           -0.361932     1.000000
# total_bedrooms       0.069814 -0.064787           -0.321531     0.932363
# population           0.101453 -0.107386           -0.296967     0.857733
# households           0.057579 -0.069959           -0.303600     0.920315
# median_income       -0.016813 -0.077507           -0.120883     0.196195
# median_house_value  -0.046228 -0.143426            0.102932     0.131417
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069814    0.101453    0.057579      -0.016813
# latitude                 -0.064787   -0.107386   -0.069959      -0.077507
# housing_median_age       -0.321531   -0.296967   -0.303600      -0.120883
# total_rooms               0.932363    0.857733    0.920315       0.196195
# total_bedrooms            1.000000    0.878384    0.979957      -0.005822
# population                0.878384    1.000000    0.907009       0.004419
# households                0.979957    0.907009    1.000000       0.014097
# median_income            -0.005822    0.004419    0.014097       1.000000
# median_house_value        0.049170   -0.025908    0.063370       0.690061
#
#                     median_house_value
# longitude                    -0.046228
# latitude                     -0.143426
# housing_median_age            0.102932
# total_rooms                   0.131417
# total_bedrooms                0.049170
# population                   -0.025908
# households                    0.063370
# median_income                 0.690061
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7216
# INLAND        5223
# NEAR OCEAN    2098
# NEAR BAY      1805
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity).astype(int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10135          1       0       0         0           0
# 15805          0       0       0         1           0
# 19572          0       1       0         0           0
# 5142           1       0       0         0           0
# 4438           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 6454           0       1       0         0           0
# 19842          0       1       0         0           0
# 1329           0       1       0         0           0
# 7840           1       0       0         0           0
# 172            0       0       0         1           0
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity).astype(int)).drop(['ocean_proximity'], axis =1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10135    -117.91     33.91                24.0     7.718685        5.940171
# 15805    -122.45     37.76                51.0     7.849714        6.126869
# 19572    -120.94     37.58                19.0     7.346010        5.913503
# 5142     -118.27     33.96                42.0     6.680855        5.318120
# 4438     -118.20     34.08                41.0     7.499977        6.063785
# ...          ...       ...                 ...          ...             ...
# 6454     -118.06     34.12                34.0     7.986845        6.326149
# 19842    -119.10     36.42                26.0     7.482119        6.033086
# 1329     -121.88     38.00                16.0     7.865572        6.089045
# 7840     -118.17     33.91                37.0     7.313220        5.666427
# 172      -122.25     37.80                36.0     7.425954        6.408529
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 10135    6.923629    5.955837         4.9766            267100.0          1
# 15805    6.698268    6.093570         5.6235            500001.0          0
# 19572    6.647688    5.916202         2.0493             99500.0          0
# 5142     6.548219    5.181784         2.0370             92600.0          1
# 4438     7.438384    6.052089         2.2222            126000.0          1
# ...           ...         ...            ...                 ...        ...
# 6454     7.415175    6.357842         4.5667            271500.0          0
# 19842    7.104965    5.950643         1.8801             57600.0          0
# 1329     7.210080    6.013715         4.1947            140300.0          0
# 7840     7.121252    5.843544         3.9333            162300.0          1
# 172      7.406103    6.298949         2.2303            116700.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 10135       0       0         0           0
# 15805       0       0         1           0
# 19572       1       0         0           0
# 5142        0       0         0           0
# 4438        0       0         0           0
# ...       ...     ...       ...         ...
# 6454        1       0         0           0
# 19842       1       0         0           0
# 1329        1       0         0           0
# 7840        0       0         0           0
# 172         0       0         1           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(numeric_only=True), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

X_train, Y_train = train_data.drop(['median_house_value'], axis = 1), train_data['median_house_value'] 

reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10135    -117.91     33.91                24.0     7.718685        5.940171
# 15805    -122.45     37.76                51.0     7.849714        6.126869
# 19572    -120.94     37.58                19.0     7.346010        5.913503
# 5142     -118.27     33.96                42.0     6.680855        5.318120
# 4438     -118.20     34.08                41.0     7.499977        6.063785
# ...          ...       ...                 ...          ...             ...
# 6454     -118.06     34.12                34.0     7.986845        6.326149
# 19842    -119.10     36.42                26.0     7.482119        6.033086
# 1329     -121.88     38.00                16.0     7.865572        6.089045
# 7840     -118.17     33.91                37.0     7.313220        5.666427
# 172      -122.25     37.80                36.0     7.425954        6.408529
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 10135    6.923629    5.955837         4.9766          1       0       0
# 15805    6.698268    6.093570         5.6235          0       0       0
# 19572    6.647688    5.916202         2.0493          0       1       0
# 5142     6.548219    5.181784         2.0370          1       0       0
# 4438     7.438384    6.052089         2.2222          1       0       0
# ...           ...         ...            ...        ...     ...     ...
# 6454     7.415175    6.357842         4.5667          0       1       0
# 19842    7.104965    5.950643         1.8801          0       1       0
# 1329     7.210080    6.013715         4.1947          0       1       0
# 7840     7.121252    5.843544         3.9333          1       0       0
# 172      7.406103    6.298949         2.2303          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 10135         0           0       0.769583         1.295987
# 15805         1           0       0.780521         1.288196
# 19572         0           0       0.804995         1.241677
# 5142          0           0       0.796024         1.289296
# 4438          0           0       0.808507         1.239238
# ...         ...         ...            ...              ...
# 6454          0           0       0.792071         1.256219
# 19842         0           0       0.806334         1.257363
# 1329          0           0       0.774139         1.307939
# 7840          0           0       0.774820         1.251504
# 172           1           0       0.862991         1.178919
#
# [16346 rows x 15 columns]

# %%
test_data = X_test.join(Y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)

test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity).astype(int)).drop(['ocean_proximity'], axis =1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

X_test, Y_test = test_data.drop(['median_house_value'], axis = 1), test_data['median_house_value']

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 
0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 10269         0           0       0.791978         1.277628
# 2589          0           1       0.794928         1.255603
# 19124         0           0       0.786164         1.286447
# 13800         0           0       0.801996         1.260519
# 10883         0           0       0.735212         1.345235
# ...         ...         ...            ...              ...
# 4090          0           0       0.801457         1.297432
# 2387          0           0       0.743005         1.376358
# 14116         0           1       0.821616         1.226920
# 12755         0           0       0.808918         1.270980
# 11589         0           0       0.751619         1.333563
#
# [4087 rows x 15 columns]

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10135    -117.91     33.91                24.0     7.718685        5.940171
# 15805    -122.45     37.76                51.0     7.849714        6.126869
# 19572    -120.94     37.58                19.0     7.346010        5.913503
# 5142     -118.27     33.96                42.0     6.680855        5.318120
# 4438     -118.20     34.08                41.0     7.499977        6.063785
# ...          ...       ...                 ...          ...             ...
# 6454     -118.06     34.12                34.0     7.986845        6.326149
# 19842    -119.10     36.42                26.0     7.482119        6.033086
# 1329     -121.88     38.00                16.0     7.865572        6.089045
# 7840     -118.17     33.91                37.0     7.313220        5.666427
# 172      -122.25     37.80                36.0     7.425954        6.408529
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 10135    6.923629    5.955837         4.9766          1       0       0
# 15805    6.698268    6.093570         5.6235          0       0       0
# 19572    6.647688    5.916202         2.0493          0       1       0
# 5142     6.548219    5.181784         2.0370          1       0       0
# 4438     7.438384    6.052089         2.2222          1       0       0
# ...           ...         ...            ...        ...     ...     ...
# 6454     7.415175    6.357842         4.5667          0       1       0
# 19842    7.104965    5.950643         1.8801          0       1       0
# 1329     7.210080    6.013715         4.1947          0       1       0
# 7840     7.121252    5.843544         3.9333          1       0       0
# 172      7.406103    6.298949         2.2303          0       0       0
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 10135         0           0       0.769583         1.295987
# 15805         1           0       0.780521         1.288196
# 19572         0           0       0.804995         1.241677
# 5142          0           0       0.796024         1.289296
# 4438          0           0       0.808507         1.239238
# ...         ...         ...            ...              ...
# 6454          0           0       0.792071         1.256219
# 19842         0           0       0.806334         1.257363
# 1329          0           0       0.774139         1.307939
# 7840          0           0       0.774820         1.251504
# 172           1           0       0.862991         1.178919
#
# [16346 rows x 15 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
reg2 = LinearRegression()
reg2.fit(X_train_s, Y_train)
# Out:
# LinearRegression()

# %%
X_test_s = scaler.transform(X_test)
reg2.score(X_test_s,Y_test)
# Out:
# 0.6648069478882108

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test, Y_test)
# Out:
# 0.818270689041802

# %%
forest2 = RandomForestRegressor()
forest2.fit(X_train_s, Y_train)
forest2.score(X_test_s, Y_test)
# Out:
# 0.8199673707249747

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators" : [200],
    "max_features" : [12 ,14],
    "min_samples_split" : [2,4,6,8]
    # "max_depth" : [None, 2, 4]
}

grid_search = GridSearchCV(forest, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_s, Y_train)
# Out:
# C:\Users\MOHAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\ma\core.py:2881: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [12, 14],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [200]},
#              scoring='neg_mean_squared_error')

# %%
 grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=12, min_samples_split=4, n_estimators=200)

# %%
best_forest =  grid_search.best_estimator_
best_forest.score(X_test_s, Y_test)
# Out:
# 0.8225684557799962
